# %%
import mxnet as mx
from mxnet import autograd, gluon, np, npx
from mxnet.gluon import nn
from d2l import mxnet as d2l

npx.set_np()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mxnet as mx
#       2 from mxnet import autograd, gluon, np, npx
#       3 from mxnet.gluon import nn
#
# File ~/opt/anaconda3/envs/d2l-ai/lib/python3.10/site-packages/mxnet/__init__.py:33
#      30 # version info
#      31 __version__ = base.__version__
# ---> 33 from . import contrib
#      34 from . import ndarray
#      35 from . import ndarray as nd
#
# File ~/opt/anaconda3/envs/d2l-ai/lib/python3.10/site-packages/mxnet/contrib/__init__.py:27
#      24 from . import symbol as sym
#      25 from . import ndarray as nd
# ---> 27 from . import autograd
#      28 from . import tensorboard
#      30 from . import text
#
# File ~/opt/anaconda3/envs/d2l-ai/lib/python3.10/site-packages/mxnet/contrib/autograd.py:27
# ...
